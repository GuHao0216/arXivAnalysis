# %%
import json

# %%
with open('cs21_paperUrl.json') as f:
    paperUrlList = json.loads(f.read())

# %%
with open('arxiv-metadata-oai-snapshot.json') as f:
    metadata = []
    content = f.readlines() 
    for line in content:
        metadata.append(json.loads(line))

# %%
len(metadata)
# Out:
# 2004644

# %%
selecteddata = []
for i in range(1403743,1585373):
    selecteddata.append(metadata[i])

# %%
len(selecteddata)
# Out:
# 181630

# %%
with open('paperInfo.json','a') as f:
    for _ in selecteddata:
            f.write(json.dumps(_)+'\n')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/xr/xhlrg8x141j0p08t8r4qz2mr0000gn/T/ipykernel_4694/2562096086.py in <module>
#       1 with open('paperInfo.json','a') as f:
# ----> 2     for _ in selecteddata:
#       3             f.write(json.dumps(_)+'\n')
#
# NameError: name 'selecteddata' is not defined

# %%
len(selecteddata)
# Out:
# 181630

# %%
with open('cs21_paperUrl.json') as f:
    paperUrlList = json.loads(f.read())

# %%
len(paperUrlList)
# Out:
# 77510

# %%
idList = []
for i,_ in enumerate(paperUrlList):
    idList.append(_.split('/')[-1])

# %%
print(idList[0])
# Out:
# 2101.00001

# %%
len(idList)
# Out:
# 77510

# %%
infolist =[]
for index,val in enumerate(idList):
    if index%100==0:
        print(index)
    for t,tval in enumerate(selecteddata[index:len(selecteddata)]):
        if val==tval['id']:
            infolist.append(tval)
            break;
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# ...

# %%
len(infolist)
# Out:
# 77253

# %%
# print(infolist)
for i in infolist:
    print(i['id'])
# Out:
# 2101.00001
# 2101.00002
# 2101.00003
# 2101.00007
# 2101.00008
# 2101.00010
# 2101.00012
# 2101.00025
# 2101.00027
# 2101.00029
# 2101.00035
# 2101.00036
# 2101.00039
# 2101.00041
# 2101.00043
# 2101.00046
# 2101.00052
# 2101.00054
# 2101.00055
# 2101.00056
# 2101.00058
# 2101.00060
# 2101.00061
# 2101.00062
# 2101.00063
# 2101.00068
# 2101.00072
# 2101.00073
# 2101.00078
# 2101.00081
# 2101.00082
# 2101.00084
# 2101.00086
# 2101.00090
# 2101.00095
# 2101.00097
# 2101.00098
# 2101.00101
# 2101.00102
# 2101.00106
# 2101.00109
# 2101.00110
# 2101.00115
# 2101.00117
# 2101.00121
# 2101.00122
# 2101.00123
# 2101.00124
# 2101.00125
# 2101.00130
# 2101.00133
# 2101.00135
# 2101.00136
# 2101.00146
# 2101.00147
# 2101.00148
# 2101.00151
# 2101.00152
# 2101.00153
# 2101.00154
# 2101.00157
# 2101.00159
# 2101.00160
# 2101.00161
# 2101.00167
# 2101.00169
# 2101.00170
# 2101.00171
# 2101.00172
# 2101.00173
# 2101.00178
# 2101.00180
# 2101.00183
# 2101.00186
# 2101.00190
# 2101.00191
# ...

# %%
print(infolist[3]['id'])
# Out:
# 2101.00007

# %%
with open('arxiv-metadata-2021-1.json','a') as f:
    for _ in infolist:
            f.write(json.dumps(_)+'\n')
